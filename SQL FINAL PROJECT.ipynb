# %%
# !pip install ipython-sql prettytable

import prettytable

prettytable.DEFAULT = 'DEFAULT'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !pip install sqlite3
# !pip install pandas 
import pandas as pd
import sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 107.5 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 112.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 41.9 MB/s eta 0:00:00
# ...

# %%
conn = sqlite3.connect("FinalDB.db")
cur = conn.cursor()

# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql sqlite:///FinalDB.db

# %%
import requests
from io import StringIO

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"
response = requests.get(url)
data = StringIO(response.text)
df=pd.read_csv(data)
df
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
url1= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"
response1 = requests.get(url1)
data1 = StringIO(response1.text)
df1=pd.read_csv(data1)
df1
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
url2= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"
response2 = requests.get(url2)
data2 = StringIO(response2.text)
df2=pd.read_csv(data2)
df2
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
df.to_sql("CENSUS_DATA",conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.to_sql("CENSUS_DATA",conn)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
# ...

# %%
df1.to_sql("CHICAGO_PUBLIC_SCHOOLS",conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df1.to_sql("CHICAGO_PUBLIC_SCHOOLS",conn)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
# ...

# %%
df2.to_sql("CHICAGO_CRIME_DATAS",conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df2.to_sql("CHICAGO_CRIME_DATAS",conn)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
# ...

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_CRIME_DATAS ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %%
# %sql SELECT name,type FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('CENSUS_DATA', 'table'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'table'),
#  ('CHICAGO_CRIME_DATAS', 'table')]

# %%
# %sql SELECT name,type FROM PRAGMA_TABLE_INFO("CHICAGO_CRIME_DATAS");
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('index', 'INTEGER'),
#  ('ID', 'INTEGER'),
#  ('CASE_NUMBER', 'TEXT'),
#  ('DATE', 'TEXT'),
#  ('BLOCK', 'TEXT'),
#  ('IUCR', 'TEXT'),
#  ('PRIMARY_TYPE', 'TEXT'),
#  ('DESCRIPTION', 'TEXT'),
#  ('LOCATION_DESCRIPTION', 'TEXT'),
#  ('ARREST', 'INTEGER'),
#  ('DOMESTIC', 'INTEGER'),
#  ('BEAT', 'INTEGER'),
#  ('DISTRICT', 'INTEGER'),
#  ('WARD', 'REAL'),
#  ('COMMUNITY_AREA_NUMBER', 'REAL'),
#  ('FBICODE', 'TEXT'),
#  ('X_COORDINATE', 'REAL'),
#  ('Y_COORDINATE', 'REAL'),
#  ('YEAR', 'INTEGER'),
#  ('LATITUDE', 'REAL'),
#  ('LONGITUDE', 'REAL'),
#  ('LOCATION', 'TEXT')]

# %%
# %sql SELECT name,type FROM PRAGMA_TABLE_INFO("CHICAGO_PUBLIC_SCHOOLS");
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('index', 'INTEGER'),
#  ('School_ID', 'INTEGER'),
#  ('NAME_OF_SCHOOL', 'TEXT'),
#  ('Elementary, Middle, or High School', 'TEXT'),
#  ('Street_Address', 'TEXT'),
#  ('City', 'TEXT'),
#  ('State', 'TEXT'),
#  ('ZIP_Code', 'INTEGER'),
#  ('Phone_Number', 'TEXT'),
#  ('Link', 'TEXT'),
#  ('Network_Manager', 'TEXT'),
#  ('Collaborative_Name', 'TEXT'),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT'),
#  ('Track_Schedule', 'TEXT'),
#  ('CPS_Performance_Policy_Status', 'TEXT'),
#  ('CPS_Performance_Policy_Level', 'TEXT'),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT'),
#  ('Safety_Icon', 'TEXT'),
#  ('SAFETY_SCORE', 'REAL'),
#  ('Family_Involvement_Icon', 'TEXT'),
#  ('Family_Involvement_Score', 'TEXT'),
#  ('Environment_Icon', 'TEXT'),
#  ('Environment_Score', 'REAL'),
#  ('Instruction_Icon', 'TEXT'),
#  ('Instruction_Score', 'REAL'),
#  ('Leaders_Icon', 'TEXT'),
#  ('Leaders_Score', 'TEXT'),
#  ('Teachers_Icon', 'TEXT'),
#  ('Teachers_Score', 'TEXT'),
# ...

# %%
# %sql SELECT name,type FROM PRAGMA_TABLE_INFO("CENSUS_DATA");
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('index', 'INTEGER'),
#  ('COMMUNITY_AREA_NUMBER', 'REAL'),
#  ('COMMUNITY_AREA_NAME', 'TEXT'),
#  ('PERCENT_OF_HOUSING_CROWDED', 'REAL'),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL'),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'REAL'),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL'),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL'),
#  ('PER_CAPITA_INCOME', 'INTEGER'),
#  ('HARDSHIP_INDEX', 'REAL')]

# %%
#1.
# %sql SELECT  COUNT(*) FROM CHICAGO_CRIME_DATAS;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %%
#2.
# %sql SELECT COMMUNITY_AREA_NAME ,COUNT( PER_CAPITA_INCOME<11000) FROM CENSUS_DATA   GROUP BY COMMUNITY_AREA_NAME;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Albany Park', 1),
#  ('Archer Heights', 1),
#  ('Armour Square', 1),
#  ('Ashburn', 1),
#  ('Auburn Gresham', 1),
#  ('Austin', 1),
#  ('Avalon Park', 1),
#  ('Avondale', 1),
#  ('Belmont Cragin', 1),
#  ('Beverly', 1),
#  ('Bridgeport', 1),
#  ('Brighton Park', 1),
#  ('Burnside', 1),
#  ('CHICAGO', 1),
#  ('Calumet Heights', 1),
#  ('Chatham', 1),
#  ('Chicago Lawn', 1),
#  ('Clearing', 1),
#  ('Douglas', 1),
#  ('Dunning', 1),
#  ('East Garfield Park', 1),
#  ('East Side', 1),
#  ('Edgewater', 1),
#  ('Edison Park', 1),
#  ('Englewood', 1),
#  ('Forest Glen', 1),
#  ('Fuller Park', 1),
#  ('Gage Park', 1),
#  ('Garfield Ridge', 1),
#  ('Grand Boulevard', 1),
#  ('Greater Grand Crossing', 1),
#  ('Hegewisch', 1),
#  ('Hermosa', 1),
#  ('Humboldt park', 1),
#  ('Hyde Park', 1),
#  ('Irving Park', 1),
#  ('Jefferson Park', 1),
#  ('Kenwood', 1),
#  ('Lake View', 1),
#  ('Lincoln Park', 1),
#  ('Lincoln Square', 1),
#  ('Logan Square', 1),
# ...

# %%
#3.
# %sql SELECT *FROM CHICAGO_CRIME_DATAS WHERE DESCRIPTION LIKE "%minor%";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(514, 3987219, 'HL266884', '2005-03-31', '024XX N CLARK ST', '2210', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 'CONVENIENCE STORE', 1, 0, 2333, 19, 43.0, 7.0, '22', 1172680.0, 1916483.0, 2005, 41.92626872, -87.64089934, '(41.926268719, -87.640899336)'),
#  (515, 3266814, 'HK238408', '2004-03-13', '093XX S STONY ISLAND AVE', '2230', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 'ALLEY', 1, 0, 413, 4, 8.0, 48.0, '22', 1188539.0, 1843379.0, 2004, 41.72530099, -87.58496589, '(41.72530099, -87.584965887)')]

# %%
#4.
# %sql SELECT * FROM CHICAGO_CRIME_DATAS WHERE PRIMARY_TYPE="KIDNAPPING";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(520, 5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
#%sql SELECT ID, Case_Number,IUCR, Primary_Type,Description,YEAR FROM CHICAGO_CRIME_DATAS;

# %%
#5.
# %sql SELECT DISTINCT PRIMARY_TYPE FROM CHICAGO_CRIME_DATAS WHERE LOCATION_DESCRIPTION="SCHOOL, PUBLIC, GROUNDS";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',)]

# %%
#%sql SELECT LOCATION_DESCRIPTION FROM CHICAGO_CRIME_DATAS

# %%
#6.
# %%sql
SELECT "Elementary, Middle, or High School", AVG(SAFETY_SCORE)
FROM "CHICAGO_PUBLIC_SCHOOLS"
GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
#7.
# %sql SELECT COMMUNITY_AREA_NAME,PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM CENSUS_DATA ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
#8.
# %sql SELECT COMMUNITY_AREA_NUMBER,COUNT(*) as number FROM CHICAGO_CRIME_DATAS GROUP BY COMMUNITY_AREA_NUMBER ORDER BY number DESC LIMIT 1  ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0, 43)]

# %%
#9.
# %sql SELECT COMMUNITY_AREA_NAME	 FROM CENSUS_DATA WHERE HARDSHIP_INDEX=(SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %%
#10.
# %sql SELECT  COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE COMMUNITY_AREA_NUMBER=(SELECT  COMMUNITY_AREA_NUMBER FROM CHICAGO_CRIME_DATAS GROUP BY  COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1)
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]

# %%
# %sql SELECT  COMMUNITY_AREA_NUMBER FROM CHICAGO_CRIME_DATAS GROUP BY  COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1 ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0,)]
